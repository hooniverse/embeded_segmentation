# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
import matplotlib.pyplot as plt
import random 

np.random.seed(42)
tf.random.set_seed(42)

# %%
def load_data(data_dir, img_size=(128,128)):
    images = []
    masks = []

    for img_file in os.listdir(data_dir):
        if '_mask' not in img_file:
            img_path = os.path.join(data_dir, img_file)
            mask_path = os.path.join(data_dir, img_file.replace('.jpg', '_mask.jpg'))

            img = load_img(img_path, target_size=img_size)
            mask = load_img(mask_path, target_size=img_size, color_mode='grayscale')

            img = img_to_array(img) / 255.0
            mask = img_to_array(mask) / 255.0

            images.append(img)
            masks.append(mask)

    return np.array(images), np.array(masks)

# %%
train_dir = '/kaggle/input/bp-datasets/split_datasets/train'
val_dir = '/kaggle/input/bp-datasets/split_datasets/val'
test_dir = '/kaggle/input/bp-datasets/split_datasets/test'

X_train, y_train = load_data(train_dir)
X_val, y_val = load_data(val_dir)
X_test, y_test= load_data(test_dir)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (608, 128, 128, 3)
# (608, 128, 128, 1)
# (110, 128, 128, 3)
# (110, 128, 128, 1)
# (55, 128, 128, 3)
# (55, 128, 128, 1)

# %%
def augment_data(images, masks, num_aug=2):
    
    datagen = ImageDataGenerator(
        rotation_range=10,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.15,
        horizontal_flip=True,
        fill_mode='nearest'
    )
    
    aug_images = []
    aug_masks = []
    
    # 원본 데이터 추가
    aug_images.extend(images)
    aug_masks.extend(masks)
    
    # 각 이미지에 대해 증강 데이터 생성
    for idx in range(len(images)):
        image = images[idx]
        mask = masks[idx]
        
        # 이미지와 마스크를 4D 텐서로 변환 (BatchSize=1)
        img_tensor = np.expand_dims(image, 0)
        mask_tensor = np.expand_dims(mask, 0)
        
        # 랜덤 시드 설정 (이미지와 마스크가 동일하게 변형되도록)
        seed = np.random.randint(1000)
        
        # 지정된 수만큼 증강 데이터 생성
        for _ in range(num_aug):
            # 이미지 증강
            datagen.fit(img_tensor)
            aug_img_iter = datagen.flow(img_tensor, seed=seed, batch_size=1)
            aug_img = next(aug_img_iter)[0]
            
            # 마스크 증강 (동일한 변환 적용)
            datagen.fit(mask_tensor)
            aug_mask_iter = datagen.flow(mask_tensor, seed=seed, batch_size=1)
            aug_mask = next(aug_mask_iter)[0]
            
            aug_images.append(aug_img)
            aug_masks.append(aug_mask)
    
    return np.array(aug_images), np.array(aug_masks)

# %%
# 학습 데이터만 증강 (각 이미지당 2개의 증강 데이터 생성)
X_train, y_train = augment_data(X_train, y_train, num_aug=2)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1824, 128, 128, 3)
# (1824, 128, 128, 1)
# (110, 128, 128, 3)
# (110, 128, 128, 1)
# (55, 128, 128, 3)
# (55, 128, 128, 1)

# %%
plt.subplot(1, 2, 1)
plt.imshow(X_train[100], cmap='gray')
plt.subplot(1, 2, 2)
plt.imshow(y_train[100], cmap='gray')

# %%
def build_unet(input_shape=(128, 128, 3)):
    inputs = layers.Input(input_shape)

    # Encoder
    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same')(pool1)
    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same')(pool2)
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)

    # Bridge
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same')(pool3)
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same')(conv4)

    # Decoder
    up7 = layers.concatenate([layers.Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(conv4), conv3], axis=3)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same')(up7)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv7)
    
    up8 = layers.concatenate([layers.Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same')(up8)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv8)
    
    up9 = layers.concatenate([layers.Conv2DTranspose(32, 2, strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(up9)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(conv9)
    outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv9)
    
    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# %%
def build_unet_dilated(input_shape=(128, 128, 3)):
    inputs = layers.Input(input_shape)
    
    # Encoder
    # First block - normal convolution to capture fine details
    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same', dilation_rate=2)(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    # Second block - increasing dilation rate
    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same', dilation_rate=2)(pool1)
    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same', dilation_rate=4)(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    # Third block - larger dilation rate for broader context
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same', dilation_rate=4)(pool2)
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same', dilation_rate=8)(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    
    # Bridge - maximum dilation rate for largest receptive field
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same', dilation_rate=8)(pool3)
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same', dilation_rate=16)(conv4)
    
    # Decoder - gradually decreasing dilation rates
    up7 = layers.concatenate([layers.Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(conv4), conv3], axis=3)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same', dilation_rate=4)(up7)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same', dilation_rate=4)(conv7)
    
    up8 = layers.concatenate([layers.Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same', dilation_rate=2)(up8)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same', dilation_rate=2)(conv8)
    
    up9 = layers.concatenate([layers.Conv2DTranspose(32, 2, strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(up9)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(conv9)
    
    outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv9)
    
    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# %%
def build_unet_same_dilated(input_shape=(128, 128, 3)):
    inputs = layers.Input(input_shape)
    
    # Encoder
    # First block
    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same', dilation_rate=2)(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    # Second block
    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same', dilation_rate=2)(pool1)
    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same', dilation_rate=2)(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    # Third block
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same', dilation_rate=2)(pool2)
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same', dilation_rate=2)(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    
    # Bridge
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same', dilation_rate=2)(pool3)
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same', dilation_rate=2)(conv4)
    
    # Decoder
    up7 = layers.concatenate([layers.Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(conv4), conv3], axis=3)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same', dilation_rate=2)(up7)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same', dilation_rate=2)(conv7)
    
    up8 = layers.concatenate([layers.Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same', dilation_rate=2)(up8)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same', dilation_rate=2)(conv8)
    
    up9 = layers.concatenate([layers.Conv2DTranspose(32, 2, strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same', dilation_rate=2)(up9)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same', dilation_rate=2)(conv9)
    
    outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv9)
    
    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# %%
def build_unet_separable(input_shape=(128, 128, 3)):
    inputs = layers.Input(input_shape)
    
    # Encoder
    # First block
    conv1 = layers.SeparableConv2D(32, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.SeparableConv2D(32, 3, activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    # Second block
    conv2 = layers.SeparableConv2D(64, 3, activation='relu', padding='same')(pool1)
    conv2 = layers.SeparableConv2D(64, 3, activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    # Third block
    conv3 = layers.SeparableConv2D(128, 3, activation='relu', padding='same')(pool2)
    conv3 = layers.SeparableConv2D(128, 3, activation='relu', padding='same')(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    
    # Bridge
    conv4 = layers.SeparableConv2D(256, 3, activation='relu', padding='same')(pool3)
    conv4 = layers.SeparableConv2D(256, 3, activation='relu', padding='same')(conv4)
    
    # Decoder
    # First block
    up7 = layers.Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(conv4)
    up7 = layers.concatenate([up7, conv3], axis=3)
    conv7 = layers.SeparableConv2D(128, 3, activation='relu', padding='same')(up7)
    conv7 = layers.SeparableConv2D(128, 3, activation='relu', padding='same')(conv7)
    
    # Second block
    up8 = layers.Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(conv7)
    up8 = layers.concatenate([up8, conv2], axis=3)
    conv8 = layers.SeparableConv2D(64, 3, activation='relu', padding='same')(up8)
    conv8 = layers.SeparableConv2D(64, 3, activation='relu', padding='same')(conv8)
    
    # Third block
    up9 = layers.Conv2DTranspose(32, 2, strides=(2, 2), padding='same')(conv8)
    up9 = layers.concatenate([up9, conv1], axis=3)
    conv9 = layers.SeparableConv2D(32, 3, activation='relu', padding='same')(up9)
    conv9 = layers.SeparableConv2D(32, 3, activation='relu', padding='same')(conv9)
    
    # Output
    outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv9)
    
    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = build_unet()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 128, 128, 32)   │            896 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 128, 128, 32)   │          9,248 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 64, 64, 32)     │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 64, 64, 64)     │         18,496 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 64, 64, 64)     │         36,928 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 32, 32, 64)     │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 32, 32, 128)    │         73,856 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 32, 32, 128)    │        147,584 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 16, 16, 128)    │              0 │ conv2d_5[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 16, 16, 256)    │        295,168 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 16, 16, 256)    │        590,080 │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 32, 32, 128)    │        131,200 │ conv2d_7[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 32, 256)    │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 32, 32, 128)    │        295,040 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 32, 32, 128)    │        147,584 │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 64, 64, 64)     │         32,832 │ conv2d_9[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 128)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 64, 64, 64)     │         73,792 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ conv2d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 128, 128, 32)   │          8,224 │ conv2d_11[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 128, 128, 64)   │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 128, 128, 32)   │         18,464 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 128, 128, 1)    │             33 │ conv2d_13[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,925,601 (7.35 MB)
#  Trainable params: 1,925,601 (7.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def dice_coef(y_true, y_pred, smooth=1e-6): # 다이스 계수
    y_pred = tf.cast(y_pred > 0.5, dtype=tf.int32)
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)
    
    intersection = tf.reduce_sum(y_true * y_pred)
    intersection = tf.cast(intersection, dtype=tf.float32)
    
    y_true = tf.reduce_sum(y_true)
    y_pred = tf.reduce_sum(y_pred)
    
    result = (2.0 *(intersection) + smooth) / (y_true + y_pred + smooth)
    
    return result
    
def dice_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)
    
def combined_loss(y_true, y_pred, a=0.95):
    logit_loss_value = tf.keras.losses.binary_crossentropy(y_true, y_pred, from_logits=False)
    dice_loss_value = dice_loss(y_true, y_pred)
    
    return a*dice_loss_value+ (1-a)*logit_loss_value

# %%
model.compile(optimizer='adam',
    loss= combined_loss,
    metrics=[dice_coef])

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_dice_coef', # validation dice coefficient
    factor=0.9, # learning rate￿ 10% ￿￿ 기존 0.9
    patience=3, # 3 epoch ￿￿ ￿￿￿ ￿기존 3￿ ￿
    min_lr=1e-6, # ￿￿ learning rate
    mode='max', # dice coefficient￿ ￿￿￿￿ ￿￿
verbose=1
)
        
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_unet_model.keras', # ￿￿￿ ￿￿￿ ￿￿￿
    monitor='val_dice_coef', # validation dice coefficient ￿￿￿￿
    save_best_only=True, # ￿￿ ￿￿ ￿￿￿ ￿￿
    mode='max',          # dice coefficient￿ ￿￿￿￿ ￿￿
    verbose=1
)

# %%
history = model.fit(X_train, y_train,
                    batch_size=16,  # 기존 16
                    epochs=50,    # 기존 50
                    validation_data=(X_val, y_val),
                    callbacks=[reduce_lr, model_checkpoint],
                    shuffle=True              # 데이터 셔플링
)
# Out:
# Epoch 1/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.0015 - loss: 0.9611
# Epoch 1: val_dice_coef improved from -inf to 0.00000, saving model to best_unet_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 18s 67ms/step - dice_coef: 0.0014 - loss: 0.9610 - val_dice_coef: 1.1786e-10 - val_loss: 0.9552 - learning_rate: 0.0010
# Epoch 2/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.0251 - loss: 0.9304
# Epoch 2: val_dice_coef improved from 0.00000 to 0.44353, saving model to best_unet_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - dice_coef: 0.0268 - loss: 0.9288 - val_dice_coef: 0.4435 - val_loss: 0.5342 - learning_rate: 0.0010
# Epoch 3/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.5413 - loss: 0.4386
# Epoch 3: val_dice_coef improved from 0.44353 to 0.57314, saving model to best_unet_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - dice_coef: 0.5421 - loss: 0.4379 - val_dice_coef: 0.5731 - val_loss: 0.4100 - learning_rate: 0.0010
# Epoch 4/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.6752 - loss: 0.3107
# Epoch 4: val_dice_coef improved from 0.57314 to 0.61808, saving model to best_unet_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - dice_coef: 0.6756 - loss: 0.3104 - val_dice_coef: 0.6181 - val_loss: 0.3666 - learning_rate: 0.0010
# Epoch 5/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7330 - loss: 0.2554
# Epoch 5: val_dice_coef did not improve from 0.61808
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.7332 - loss: 0.2553 - val_dice_coef: 0.6096 - val_loss: 0.3754 - learning_rate: 0.0010
# Epoch 6/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7549 - loss: 0.2345
# Epoch 6: val_dice_coef did not improve from 0.61808
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.7550 - loss: 0.2344 - val_dice_coef: 0.5779 - val_loss: 0.4056 - learning_rate: 0.0010
# Epoch 7/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7702 - loss: 0.2199
# Epoch 7: val_dice_coef improved from 0.61808 to 0.69806, saving model to best_unet_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - dice_coef: 0.7703 - loss: 0.2198 - val_dice_coef: 0.6981 - val_loss: 0.2907 - learning_rate: 0.0010
# Epoch 8/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7873 - loss: 0.2035
# Epoch 8: val_dice_coef did not improve from 0.69806
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.7874 - loss: 0.2034 - val_dice_coef: 0.6938 - val_loss: 0.2946 - learning_rate: 0.0010
# Epoch 9/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7992 - loss: 0.1921
# Epoch 9: val_dice_coef did not improve from 0.69806
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.7992 - loss: 0.1921 - val_dice_coef: 0.6889 - val_loss: 0.2990 - learning_rate: 0.0010
# Epoch 10/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8050 - loss: 0.1865
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 10: val_dice_coef did not improve from 0.69806
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8051 - loss: 0.1864 - val_dice_coef: 0.6887 - val_loss: 0.2994 - learning_rate: 0.0010
# Epoch 11/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8143 - loss: 0.1777
# Epoch 11: val_dice_coef improved from 0.69806 to 0.71742, saving model to best_unet_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - dice_coef: 0.8143 - loss: 0.1776 - val_dice_coef: 0.7174 - val_loss: 0.2719 - learning_rate: 9.0000e-04
# Epoch 12/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8218 - loss: 0.1705
# Epoch 12: val_dice_coef did not improve from 0.71742
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8218 - loss: 0.1704 - val_dice_coef: 0.6592 - val_loss: 0.3282 - learning_rate: 9.0000e-04
# Epoch 13/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8303 - loss: 0.1624
# Epoch 13: val_dice_coef did not improve from 0.71742
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8303 - loss: 0.1623 - val_dice_coef: 0.6733 - val_loss: 0.3150 - learning_rate: 9.0000e-04
# Epoch 14/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8355 - loss: 0.1574
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
#
# Epoch 14: val_dice_coef did not improve from 0.71742
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8356 - loss: 0.1573 - val_dice_coef: 0.7100 - val_loss: 0.2793 - learning_rate: 9.0000e-04
# Epoch 15/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8426 - loss: 0.1506
# Epoch 15: val_dice_coef improved from 0.71742 to 0.72262, saving model to best_unet_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - dice_coef: 0.8427 - loss: 0.1505 - val_dice_coef: 0.7226 - val_loss: 0.2667 - learning_rate: 8.1000e-04
# Epoch 16/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8500 - loss: 0.1435
# Epoch 16: val_dice_coef did not improve from 0.72262
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8500 - loss: 0.1435 - val_dice_coef: 0.7054 - val_loss: 0.2837 - learning_rate: 8.1000e-04
# Epoch 17/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8607 - loss: 0.1332
# Epoch 17: val_dice_coef improved from 0.72262 to 0.72412, saving model to best_unet_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - dice_coef: 0.8608 - loss: 0.1332 - val_dice_coef: 0.7241 - val_loss: 0.2652 - learning_rate: 8.1000e-04
# Epoch 18/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8636 - loss: 0.1305
# Epoch 18: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8637 - loss: 0.1304 - val_dice_coef: 0.7188 - val_loss: 0.2708 - learning_rate: 8.1000e-04
# Epoch 19/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8681 - loss: 0.1261
# Epoch 19: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8681 - loss: 0.1261 - val_dice_coef: 0.7122 - val_loss: 0.2775 - learning_rate: 8.1000e-04
# Epoch 20/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8665 - loss: 0.1277
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
#
# Epoch 20: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8665 - loss: 0.1277 - val_dice_coef: 0.7056 - val_loss: 0.2837 - learning_rate: 8.1000e-04
# Epoch 21/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8668 - loss: 0.1275
# Epoch 21: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8668 - loss: 0.1274 - val_dice_coef: 0.7106 - val_loss: 0.2790 - learning_rate: 7.2900e-04
# Epoch 22/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8738 - loss: 0.1208
# Epoch 22: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8738 - loss: 0.1207 - val_dice_coef: 0.7142 - val_loss: 0.2748 - learning_rate: 7.2900e-04
# Epoch 23/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8750 - loss: 0.1195
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
#
# Epoch 23: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8750 - loss: 0.1195 - val_dice_coef: 0.7158 - val_loss: 0.2737 - learning_rate: 7.2900e-04
# Epoch 24/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8789 - loss: 0.1158
# Epoch 24: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8790 - loss: 0.1158 - val_dice_coef: 0.7129 - val_loss: 0.2767 - learning_rate: 6.5610e-04
# Epoch 25/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8782 - loss: 0.1165
# Epoch 25: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8783 - loss: 0.1164 - val_dice_coef: 0.7017 - val_loss: 0.2879 - learning_rate: 6.5610e-04
# Epoch 26/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8845 - loss: 0.1105
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
#
# Epoch 26: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8845 - loss: 0.1105 - val_dice_coef: 0.6735 - val_loss: 0.3154 - learning_rate: 6.5610e-04
# Epoch 27/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8854 - loss: 0.1097
# Epoch 27: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8854 - loss: 0.1097 - val_dice_coef: 0.6950 - val_loss: 0.2943 - learning_rate: 5.9049e-04
# Epoch 28/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8895 - loss: 0.1057
# Epoch 28: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8895 - loss: 0.1057 - val_dice_coef: 0.6895 - val_loss: 0.2998 - learning_rate: 5.9049e-04
# Epoch 29/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8925 - loss: 0.1028
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005314410547725857.
#
# Epoch 29: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8925 - loss: 0.1028 - val_dice_coef: 0.6945 - val_loss: 0.2941 - learning_rate: 5.9049e-04
# Epoch 30/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8960 - loss: 0.0994
# Epoch 30: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8961 - loss: 0.0994 - val_dice_coef: 0.6809 - val_loss: 0.3080 - learning_rate: 5.3144e-04
# Epoch 31/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8961 - loss: 0.0994
# Epoch 31: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8962 - loss: 0.0993 - val_dice_coef: 0.6824 - val_loss: 0.3072 - learning_rate: 5.3144e-04
# Epoch 32/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8986 - loss: 0.0970
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00047829695977270604.
#
# Epoch 32: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.8987 - loss: 0.0969 - val_dice_coef: 0.6790 - val_loss: 0.3110 - learning_rate: 5.3144e-04
# Epoch 33/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9024 - loss: 0.0934
# Epoch 33: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9024 - loss: 0.0933 - val_dice_coef: 0.6632 - val_loss: 0.3264 - learning_rate: 4.7830e-04
# Epoch 34/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9035 - loss: 0.0923
# Epoch 34: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9036 - loss: 0.0922 - val_dice_coef: 0.6606 - val_loss: 0.3289 - learning_rate: 4.7830e-04
# Epoch 35/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9061 - loss: 0.0898
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0004304672533180565.
#
# Epoch 35: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9062 - loss: 0.0897 - val_dice_coef: 0.6743 - val_loss: 0.3152 - learning_rate: 4.7830e-04
# Epoch 36/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9105 - loss: 0.0856
# Epoch 36: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9105 - loss: 0.0856 - val_dice_coef: 0.6739 - val_loss: 0.3154 - learning_rate: 4.3047e-04
# Epoch 37/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9125 - loss: 0.0837
# Epoch 37: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9126 - loss: 0.0836 - val_dice_coef: 0.6530 - val_loss: 0.3362 - learning_rate: 4.3047e-04
# Epoch 38/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9142 - loss: 0.0820
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00038742052274756136.
#
# Epoch 38: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9143 - loss: 0.0820 - val_dice_coef: 0.6692 - val_loss: 0.3209 - learning_rate: 4.3047e-04
# Epoch 39/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9144 - loss: 0.0819
# Epoch 39: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9144 - loss: 0.0819 - val_dice_coef: 0.6568 - val_loss: 0.3317 - learning_rate: 3.8742e-04
# Epoch 40/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9162 - loss: 0.0801
# Epoch 40: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9163 - loss: 0.0801 - val_dice_coef: 0.6799 - val_loss: 0.3089 - learning_rate: 3.8742e-04
# Epoch 41/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9175 - loss: 0.0789
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0003486784757114947.
#
# Epoch 41: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9175 - loss: 0.0789 - val_dice_coef: 0.6833 - val_loss: 0.3068 - learning_rate: 3.8742e-04
# Epoch 42/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9196 - loss: 0.0769
# Epoch 42: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9196 - loss: 0.0769 - val_dice_coef: 0.6831 - val_loss: 0.3066 - learning_rate: 3.4868e-04
# Epoch 43/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9255 - loss: 0.0713
# Epoch 43: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9256 - loss: 0.0712 - val_dice_coef: 0.6785 - val_loss: 0.3116 - learning_rate: 3.4868e-04
# Epoch 44/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9285 - loss: 0.0684
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.00031381062290165574.
#
# Epoch 44: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9285 - loss: 0.0684 - val_dice_coef: 0.6744 - val_loss: 0.3154 - learning_rate: 3.4868e-04
# Epoch 45/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9306 - loss: 0.0663
# Epoch 45: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9307 - loss: 0.0663 - val_dice_coef: 0.6612 - val_loss: 0.3280 - learning_rate: 3.1381e-04
# Epoch 46/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9288 - loss: 0.0681
# Epoch 46: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9288 - loss: 0.0681 - val_dice_coef: 0.6762 - val_loss: 0.3135 - learning_rate: 3.1381e-04
# Epoch 47/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9292 - loss: 0.0678
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0002824295632308349.
#
# Epoch 47: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9292 - loss: 0.0677 - val_dice_coef: 0.6935 - val_loss: 0.2960 - learning_rate: 3.1381e-04
# Epoch 48/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9312 - loss: 0.0659
# Epoch 48: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9312 - loss: 0.0658 - val_dice_coef: 0.6833 - val_loss: 0.3054 - learning_rate: 2.8243e-04
# Epoch 49/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9303 - loss: 0.0667
# Epoch 49: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9304 - loss: 0.0666 - val_dice_coef: 0.6865 - val_loss: 0.3032 - learning_rate: 2.8243e-04
# Epoch 50/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9337 - loss: 0.0635
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.00025418660952709616.
#
# Epoch 50: val_dice_coef did not improve from 0.72412
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - dice_coef: 0.9337 - loss: 0.0634 - val_dice_coef: 0.6689 - val_loss: 0.3213 - learning_rate: 2.8243e-04

# %%
best_model = tf.keras.models.load_model('best_unet_model.keras',
    custom_objects={
        'combined_loss': combined_loss,
        'dice_coef': dice_coef})

start_time = tf.timestamp()
test_loss, test_dice = best_model.evaluate(X_test, y_test)
end_time = tf.timestamp()
print(f"Inference time: {end_time - start_time} seconds")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - dice_coef: 0.4108 - loss: 0.5639
# Inference time: 5.320204019546509 seconds

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Model dice_coef')
plt.ylabel('dice_coef')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
def visualize_results(model, X, y, num_samples=3):
    predictions = model.predict(X[:num_samples])
    predictions = (predictions > 0.5).astype(np.float32)
    
    plt.figure(figsize=(4 * num_samples, 12))
    for i in range(num_samples):
        # 원본 이미지 출력
        plt.subplot(3, num_samples, i + 1)
        plt.imshow(X[i])
        plt.title('Original Image')
        plt.axis('off')
        
        # 실제 마스크 출력
        plt.subplot(3, num_samples, i + 1 + num_samples)
        plt.imshow(y[i, :, :, 0], cmap='gray')
        plt.title(f'True Mask\nDice: {dice_coef(y[i:i+1], predictions[i:i+1]).numpy():.4f}')
        plt.axis('off')
        
        # 예측 마스크 출력
        plt.subplot(3, num_samples, i + 1 + 2 * num_samples)
        plt.imshow(predictions[i, :, :, 0], cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# 함수 호출 예시
visualize_results(model, X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step

# %%
import tensorflow as tf
import time
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

def calculate_flops(model, input_shape=(1, 128, 128, 3)):
    # 모델을 ConcreteFunction으로 변환
    concrete_func = tf.function(lambda x: model(x))
    concrete_func = concrete_func.get_concrete_function(
        tf.TensorSpec(input_shape, tf.float32)
    )

    # Graph를 Frozen하여 FLOPs 계산
    frozen_func = convert_variables_to_constants_v2(concrete_func)
    frozen_graph = frozen_func.graph

    # TensorFlow Profiler를 사용하여 FLOPs 계산
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()

    # tf.compat.v1.profiler을 사용하여 계산
    flops = tf.compat.v1.profiler.profile(
        graph=frozen_graph,
        run_meta=run_meta,
        options=opts
    )

    return flops.total_float_ops  # Total FLOPs


def measure_inference_time(model, X, num_samples=10):
    start_time = time.time()
    for _ in range(num_samples):
        model.predict(X[:1])
    end_time = time.time()
    avg_inference_time = (end_time - start_time) / num_samples
    return avg_inference_time

# FLOPs 계산
flops = calculate_flops(model)
print(f"FLOPs: {flops / 1e9:.3f} GFLOPs")
# Out:
# FLOPs: 4.615 GFLOPs
